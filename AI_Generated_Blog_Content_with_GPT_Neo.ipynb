# %% [markdown]
# <a href="https://colab.research.google.com/github/bismilahsugih/testWP/blob/gh-pages/AI_Generated_Blog_Content_with_GPT_Neo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q gradio
# !pip install -q aitextgen
# Out:
#      |████████████████████████████████| 5.1 MB 20.3 MB/s
#      |████████████████████████████████| 84 kB 4.0 MB/s
#      |████████████████████████████████| 54 kB 1.9 MB/s
#      |████████████████████████████████| 57 kB 5.9 MB/s
#      |████████████████████████████████| 1.1 MB 68.2 MB/s
#      |████████████████████████████████| 140 kB 6.4 MB/s
#      |████████████████████████████████| 272 kB 71.4 MB/s
#      |████████████████████████████████| 212 kB 63.8 MB/s
#      |████████████████████████████████| 2.3 MB 65.4 MB/s
#      |████████████████████████████████| 84 kB 3.2 MB/s
#      |████████████████████████████████| 271 kB 76.7 MB/s
#      |████████████████████████████████| 144 kB 73.1 MB/s
#      |████████████████████████████████| 94 kB 3.9 MB/s
#      |████████████████████████████████| 63 kB 2.4 MB/s
#      |████████████████████████████████| 80 kB 10.5 MB/s
#      |████████████████████████████████| 68 kB 8.0 MB/s
#      |████████████████████████████████| 54 kB 3.3 MB/s
# ...

# %%
import gradio as gr
from aitextgen import aitextgen

# %%
# Download GPT-Neo Model

# %%
ai = aitextgen(model="EleutherAI/gpt-neo-125M",to_gpu=True)
# Out:
# https://huggingface.co/EleutherAI/gpt-neo-125M/resolve/main/config.json not found in cache or force_download set to True, downloading to /content/aitextgen/tmp75y13w3w
# Downloading:   0%|          | 0.00/0.98k [00:00<?, ?B/s]
# storing https://huggingface.co/EleutherAI/gpt-neo-125M/resolve/main/config.json in cache at aitextgen/29380fef22a43cbfb3d3a6c8e2f4fd951459584d87c34e4621b30580a54aca84.f0f7ebddfc6e15a23ac33e7fa95cd8cca05edf87cc74f9e3be7905f538a59762
# creating metadata file for aitextgen/29380fef22a43cbfb3d3a6c8e2f4fd951459584d87c34e4621b30580a54aca84.f0f7ebddfc6e15a23ac33e7fa95cd8cca05edf87cc74f9e3be7905f538a59762
# https://huggingface.co/EleutherAI/gpt-neo-125M/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /content/aitextgen/tmpazbyx1qw
# Downloading:   0%|          | 0.00/502M [00:00<?, ?B/s]
# ...

# %%
def ai_text(inp):
  generated_text = ai.generate_one(max_length = 1000, prompt = inp, no_repeat_ngram_size = 3) #repetition_penalty = 1.9)
  #print(type(generated_text))
  return generated_text

# %%
ai_text("USA is a leading manufacturer in smartphone and that is ")
# Out:
# 'USA is a leading manufacturer in smartphone and that is \na company in the development of new devices.\n\nThe company was founded in the year 2000 and was a pioneer in\nthe development of iPhone, iPad and iPad Mini.\nA few years after the product was introduced, the company’s\nnew smartphone was released and the company was able to develop\nthe next generation. It was also one of the first to develop a\nmobile phone with a small screen.\nThe new iPhone, iPhone 6 and iPhone 6 Plus are just the tip of\nthe iceberg.\nIn the next year, the new iPhone mini will be released in the\nnext few months. The new iPhone also has an improved screen\nwhich will allow the company to deliver a more modern device.\nBut, the iPhone is not a mobile phone and can be used in many\nother ways.\nThere are many other companies that are developing new devices\nand smartphones and that includes Google.\nAs we can see from the above, the companies that have the\nlatest device are Google, Samsung, Apple and Mic
# ...

# %%
output_text = gr.outputs.Textbox()
gr.Interface(ai_text,"textbox", output_text, title="ai generated Blog with GPT-Neo",
             description="AI Generated Blog Content with GPT-Neo - via {aitextgen}").launch()
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://30390.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://30390.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f8843422950>,
#  'http://127.0.0.1:7860/',
#  'https://30390.gradio.app')
